# %%
#Loading Best Models
from tensorflow.keras.models import load_model
models = []

#Choosing Best Models
model_files = [
    r"./model/Skin Cancer Models/model1.h5",
    r"../model/Skin Cancer Models/model2.h5",
    r"../model/Skin Cancer Models/model3.h5",
]

for file in model_files:
  print(f"Loading {file}...")
  models.append(load_model(file, compile=True))
# Out:
# Loading ../model/Skin Cancer Models/model1.h5...
# d:\Program Files\Python\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 14
#      12 for file in model_files:
#      13   print(f"Loading {file}...")
# ---> 14   models.append(load_model(file, compile=True))
#
# File d:\Program Files\Python\lib\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File d:\Program Files\Python\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:155, in load_model_from_hdf5(filepath, custom_objects, compile)
#     151 training_config = json_utils.decode(training_config)
#     153 # Compile model.
#     154 model.compile(
# --> 155     **saving_utils.compile_args_from_training_config(
#     156         training_config, custom_objects
#     157     )
#     158 )
#     159 saving_utils.try_build_compiled_arguments(model)
#     161 # Set optimizer weights.
#
# File d:\Program Files\Python\lib\site-packages\keras\src\legacy\saving\saving_utils.py:143, in compile_args_from_training_config(training_config, custom_objects)
#     141 loss_config = training_config.get("loss", None)
#     142 if loss_config is not None:
# --> 143     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     144     # Ensure backwards compatibility for losses in legacy H5 files
#     145     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#
# File d:\Program Files\Python\lib\site-packages\keras\src\legacy\saving\saving_utils.py:202, in _deserialize_nested_config(deserialize_fn, config)
#     200     return None
#     201 if _is_single_object(config):
# --> 202     return deserialize_fn(config)
#     203 elif isinstance(config, dict):
#     204     return {
#     205         k: _deserialize_nested_config(deserialize_fn, v)
#     206         for k, v in config.items()
#     207     }
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\__init__.py:124, in deserialize(name, custom_objects)
#     111 @keras_export("keras.losses.deserialize")
#     112 def deserialize(name, custom_objects=None):
#     113     """Deserializes a serialized loss class/function instance.
#     114
#     115     Args:
#    (...)
#     122         A Keras `Loss` instance or a loss function.
#     123     """
# --> 124     return serialization_lib.deserialize_keras_object(
#     125         name,
#     126         module_objects=ALL_OBJECTS_DICT,
#     127         custom_objects=custom_objects,
#     128     )
#
# File d:\Program Files\Python\lib\site-packages\keras\src\saving\serialization_lib.py:576, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     569         if isinstance(module_objects[config], types.FunctionType):
#     570             return deserialize_keras_object(
#     571                 serialize_with_public_fn(
#     572                     module_objects[config], config, fn_module_name
#     573                 ),
#     574                 custom_objects=custom_objects,
#     575             )
# --> 576         return deserialize_keras_object(
#     577             serialize_with_public_class(
#     578                 module_objects[config], inner_config=inner_config
#     579             ),
#     580             custom_objects=custom_objects,
#     581         )
#     583 if isinstance(config, PLAIN_TYPES):
#     584     return config
#
# File d:\Program Files\Python\lib\site-packages\keras\src\saving\serialization_lib.py:711, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     709 with custom_obj_scope, safe_mode_scope:
#     710     try:
# --> 711         instance = cls.from_config(inner_config)
#     712     except TypeError as e:
#     713         raise TypeError(
#     714             f"{cls} could not be deserialized properly. Please"
#     715             " ensure that components that are Python object"
#    (...)
#     719             f"\n\nconfig={config}.\n\nException encountered: {e}"
#     720         )
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\losses.py:34, in LossFunctionWrapper.from_config(cls, config)
#      32 if "fn" in config:
#      33     config = serialization_lib.deserialize_keras_object(config)
# ---> 34 return cls(**config)
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\losses.py:963, in SparseCategoricalCrossentropy.__init__(self, from_logits, ignore_class, reduction, name)
#     956 def __init__(
#     957     self,
#     958     from_logits=False,
#    (...)
#     961     name="sparse_categorical_crossentropy",
#     962 ):
# --> 963     super().__init__(
#     964         sparse_categorical_crossentropy,
#     965         name=name,
#     966         reduction=reduction,
#     967         from_logits=from_logits,
#     968         ignore_class=ignore_class,
#     969     )
#     970     self.from_logits = from_logits
#     971     self.ignore_class = ignore_class
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\losses.py:16, in LossFunctionWrapper.__init__(self, fn, reduction, name, **kwargs)
#      13 def __init__(
#      14     self, fn, reduction="sum_over_batch_size", name=None, **kwargs
#      15 ):
# ---> 16     super().__init__(reduction=reduction, name=name)
#      17     self.fn = fn
#      18     self._fn_kwargs = kwargs
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\loss.py:29, in Loss.__init__(self, name, reduction, dtype)
#      27 def __init__(self, name=None, reduction="sum_over_batch_size", dtype=None):
#      28     self.name = name or auto_name(self.__class__.__name__)
# ---> 29     self.reduction = standardize_reduction(reduction)
#      30     self.dtype = dtype or backend.floatx()
#
# File d:\Program Files\Python\lib\site-packages\keras\src\losses\loss.py:77, in standardize_reduction(reduction)
#      75 allowed = {"sum_over_batch_size", "sum", None, "none"}
#      76 if reduction not in allowed:
# ---> 77     raise ValueError(
#      78         "Invalid value for argument `reduction`. "
#      79         f"Expected one of {allowed}. Received: "
#      80         f"reduction={reduction}"
#      81     )
#      82 return reduction
#
# ValueError: Invalid value for argument `reduction`. Expected one of {'none', 'sum', 'sum_over_batch_size', None}. Received: reduction=auto
